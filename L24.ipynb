# %%
#Campus Entry System
authorised_students = []
students_on_campus = []

def menu():
    print("Welcome to the Campus Entry System")
    print("1. Record Entry")
    print("2. Record Exit")
    print("3. View Current List")
    print("4. Add Student to Authorised List")
    print("5. View Unauthorised Entry Attempts")
    print("6. Exit")
menu()
def record_entry(student_id):
    student_id = int(input("Enter student ID: "))
def record_exit(student_id):
def view_current_list():
    print("Students currently on campus:")
    for student in students_on_campus:
        print(student)
def add_student(student_id):
def view_unauthorised_attempts():
def main():
    while True:
        choice = input("Enter your choice: ")
        if choice == "1":
            student_id = input("Enter student ID: ")
            record_entry(student_id)
        elif choice == "2":
            student_id = input("Enter student ID: ")
            record_exit(student_id)
        elif choice == "3":
            view_current_list()
        elif choice == "4":
            student_id = input("Enter student ID to add to authorised list: ")
            add_student(student_id)
        elif choice == "5":
            view_unauthorised_attempts()
        elif choice == "6":
            print("Exiting the system.")
            break
        else:
            print("Invalid choice. Please try again.")
main()
# Out:
# Welcome to the Campus Entry System
# 1. Record Entry
# 2. Record Exit
# 3. View Current List
# 4. Add Student to Authorised List
# 5. View Unauthorised Entry Attempts
# 6. Exit
# Exiting the system.
